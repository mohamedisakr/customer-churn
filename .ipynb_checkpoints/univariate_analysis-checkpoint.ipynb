# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings(action = 'ignore')

# %%
#importing data
data = pd.read_csv("raw_data\churn.csv")

# %%
#first 5 instances using "head()" function
data.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
# memory usage
data.memory_usage()
# Out:
# Index                 128
# customerID          56344
# gender              56344
# SeniorCitizen       56344
# Partner             56344
# Dependents          56344
# tenure              56344
# PhoneService        56344
# MultipleLines       56344
# InternetService     56344
# OnlineSecurity      56344
# OnlineBackup        56344
# DeviceProtection    56344
# TechSupport         56344
# StreamingTV         56344
# StreamingMovies     56344
# Contract            56344
# PaperlessBilling    56344
# PaymentMethod       56344
# MonthlyCharges      56344
# TotalCharges        56344
# Churn               56344
# dtype: int64

# %%
# the shape (rows, columns)
data.shape
# Out:
# (7043, 21)

# %%
# printing all the columns
data.columns.values.tolist()
# Out:
# ['customerID',
#  'gender',
#  'SeniorCitizen',
#  'Partner',
#  'Dependents',
#  'tenure',
#  'PhoneService',
#  'MultipleLines',
#  'InternetService',
#  'OnlineSecurity',
#  'OnlineBackup',
#  'DeviceProtection',
#  'TechSupport',
#  'StreamingTV',
#  'StreamingMovies',
#  'Contract',
#  'PaperlessBilling',
#  'PaymentMethod',
#  'MonthlyCharges',
#  'TotalCharges',
#  'Churn']

# %% [markdown]
# ### Variable Identification and Typecasting

# %%
def convert_column_name(column_name):
    # column_name is a string representing a column name in pascal case
    # returns a string representing the same column name in snake_case
    import re # import regular expression module
    # insert underscores before uppercase letters and convert to lowercase
    return re.sub(r'(?<!^)(?=[A-Z])', '_', column_name).lower()

# %%
data.columns = [convert_column_name(col) for col in data.columns]

# %%
data.rename(columns={'customer_i_d': 'customer_id', 'streaming_t_v': 'streaming_tv'}, inplace=True)

# %%
# data types
data.dtypes
# Out:
# customer_id           object
# gender                object
# senior_citizen         int64
# partner               object
# dependents            object
# tenure                 int64
# phone_service         object
# multiple_lines        object
# internet_service      object
# online_security       object
# online_backup         object
# device_protection     object
# tech_support          object
# streaming_tv          object
# streaming_movies      object
# contract              object
# paperless_billing     object
# payment_method        object
# monthly_charges      float64
# total_charges         object
# churn                 object
# dtype: object

# %% [markdown]
# ##### Integer Data Type

# %%
# Identifying variables with integer datatype
data.dtypes[data.dtypes == 'int64']
# Out:
# senior_citizen    int64
# tenure            int64
# dtype: object

# %%
data['senior_citizen'].value_counts()
# Out:
# 0    5901
# 1    1142
# Name: senior_citizen, dtype: int64

# %%
data['senior_citizen'] = data['senior_citizen'].astype('category')

# %%
data['senior_citizen'].dtypes
# Out:
# CategoricalDtype(categories=[0, 1], ordered=False)

# %%
data['tenure'].value_counts()
# Out:
# 1     613
# 72    362
# 2     238
# 3     200
# 4     176
#      ...
# 28     57
# 39     56
# 44     51
# 36     50
# 0      11
# Name: tenure, Length: 73, dtype: int64

# %% [markdown]
# ##### Float Data Type

# %%
# Identifying variables with float datatype
data.dtypes[data.dtypes == 'float64']
# Out:
# monthly_charges    float64
# dtype: object

# %%
data['monthly_charges'].value_counts()
# Out:
# 20.05     61
# 19.85     45
# 19.95     44
# 19.90     44
# 20.00     43
#           ..
# 23.65      1
# 114.70     1
# 43.65      1
# 87.80      1
# 78.70      1
# Name: monthly_charges, Length: 1585, dtype: int64

# %%
data['total_charges'].value_counts()
# Out:
#           11
# 20.2      11
# 19.75      9
# 20.05      8
# 19.9       8
#           ..
# 6849.4     1
# 692.35     1
# 130.15     1
# 3211.9     1
# 6844.5     1
# Name: total_charges, Length: 6531, dtype: int64

# %%
data['total_charges'].isna().sum()
# Out:
# 0

# %%
data['total_charges'].isnull().sum()
# Out:
# 0

# %%
data['total_charges'] = pd.to_numeric(data['total_charges'], errors='coerce')
data['total_charges'] = data['total_charges'].astype('float')

# %%
data['total_charges'].dtypes
# Out:
# dtype('float64')

# %% [markdown]
# ##### Object Data Type

# %%
data.dtypes
# Out:
# customer_id            object
# gender                 object
# senior_citizen       category
# partner                object
# dependents             object
# tenure                  int64
# phone_service          object
# multiple_lines         object
# internet_service       object
# online_security        object
# online_backup          object
# device_protection      object
# tech_support           object
# streaming_tv           object
# streaming_movies       object
# contract               object
# paperless_billing      object
# payment_method         object
# monthly_charges       float64
# total_charges         float64
# churn                  object
# dtype: object

# %%
data['customer_id'].value_counts()
# Out:
# 7590-VHVEG    1
# 3791-LGQCY    1
# 6008-NAIXK    1
# 5956-YHHRX    1
# 5365-LLFYV    1
#              ..
# 9796-MVYXX    1
# 2637-FKFSY    1
# 1552-AAGRX    1
# 4304-TSPVK    1
# 3186-AJIEK    1
# Name: customer_id, Length: 7043, dtype: int64

# %%
data['gender'].value_counts()
# Out:
# Male      3555
# Female    3488
# Name: gender, dtype: int64

# %%
data['gender'] = data['gender'].astype('category')

# %%
data['gender'].dtypes
# Out:
# CategoricalDtype(categories=['Female', 'Male'], ordered=False)

# %%
data['partner'].value_counts()
# Out:
# No     3641
# Yes    3402
# Name: partner, dtype: int64

# %%
data['partner'] = data['partner'].astype('category')

# %%
data['partner'].dtypes
# Out:
# CategoricalDtype(categories=['No', 'Yes'], ordered=False)

# %%
data['dependents'].dtype
# Out:
# dtype('O')

# %%
data['dependents'].value_counts()
# Out:
# No     4933
# Yes    2110
# Name: dependents, dtype: int64

# %%
data['dependents'] = data['dependents'].astype('category')

# %%
data['dependents'].dtypes
# Out:
# CategoricalDtype(categories=['No', 'Yes'], ordered=False)

# %%
data['phone_service'].value_counts()
# Out:
# Yes    6361
# No      682
# Name: phone_service, dtype: int64

# %%
data['phone_service'] = data['phone_service'].astype('category')

# %%
data['phone_service'].dtypes
# Out:
# CategoricalDtype(categories=['No', 'Yes'], ordered=False)

# %%
data['multiple_lines'].value_counts()
# Out:
# No                  3390
# Yes                 2971
# No phone service     682
# Name: multiple_lines, dtype: int64

# %%
data['multiple_lines'] = data['multiple_lines'].astype('category')

# %%
data['multiple_lines'].dtypes
# Out:
# CategoricalDtype(categories=['No', 'No phone service', 'Yes'], ordered=False)

# %%
data['internet_service'].value_counts()
# Out:
# Fiber optic    3096
# DSL            2421
# No             1526
# Name: internet_service, dtype: int64

# %%
data['internet_service'] = data['internet_service'].astype('category')

# %%
data['internet_service'].dtypes
# Out:
# CategoricalDtype(categories=['DSL', 'Fiber optic', 'No'], ordered=False)

# %%
data['online_security'].value_counts()
# Out:
# No                     3498
# Yes                    2019
# No internet service    1526
# Name: online_security, dtype: int64

# %%
data['online_security'] = data['online_security'].astype('category')

# %%
data['online_security'].dtypes
# Out:
# CategoricalDtype(categories=['No', 'No internet service', 'Yes'], ordered=False)

# %%
data['online_backup'].value_counts()
# Out:
# No                     3088
# Yes                    2429
# No internet service    1526
# Name: online_backup, dtype: int64

# %%
data['online_backup'] = data['online_backup'].astype('category')

# %%
data['online_backup'].dtypes
# Out:
# CategoricalDtype(categories=['No', 'No internet service', 'Yes'], ordered=False)

# %%
data['device_protection'].value_counts()
# Out:
# No                     3095
# Yes                    2422
# No internet service    1526
# Name: device_protection, dtype: int64

# %%
data['device_protection'] = data['device_protection'].astype('category')

# %%
data['device_protection'].dtypes
# Out:
# CategoricalDtype(categories=['No', 'No internet service', 'Yes'], ordered=False)

# %%
data['tech_support'].value_counts()
# Out:
# No                     3473
# Yes                    2044
# No internet service    1526
# Name: tech_support, dtype: int64

# %%
data['tech_support'] = data['tech_support'].astype('category')

# %%
data['tech_support'].dtypes
# Out:
# CategoricalDtype(categories=['No', 'No internet service', 'Yes'], ordered=False)

# %%
data['streaming_tv'].value_counts()
# Out:
# No                     2810
# Yes                    2707
# No internet service    1526
# Name: streaming_tv, dtype: int64

# %%
data['streaming_tv'] = data['streaming_tv'].astype('category')

# %%
data['streaming_tv'].dtypes
# Out:
# CategoricalDtype(categories=['No', 'No internet service', 'Yes'], ordered=False)

# %%
data['streaming_movies'].value_counts()
# Out:
# No                     2785
# Yes                    2732
# No internet service    1526
# Name: streaming_movies, dtype: int64

# %%
data['streaming_movies'] = data['streaming_movies'].astype('category')

# %%
data['streaming_movies'].dtypes
# Out:
# CategoricalDtype(categories=['No', 'No internet service', 'Yes'], ordered=False)

# %%
data['contract'].value_counts()
# Out:
# Month-to-month    3875
# Two year          1695
# One year          1473
# Name: contract, dtype: int64

# %%
data['contract'] = data['contract'].astype('category')

# %%
data['contract'].dtypes
# Out:
# CategoricalDtype(categories=['Month-to-month', 'One year', 'Two year'], ordered=False)

# %%
data['paperless_billing'].value_counts()
# Out:
# Yes    4171
# No     2872
# Name: paperless_billing, dtype: int64

# %%
data['paperless_billing'] = data['paperless_billing'].astype('category')

# %%
data['paperless_billing'].dtypes
# Out:
# CategoricalDtype(categories=['No', 'Yes'], ordered=False)

# %%
data['payment_method'].value_counts()
# Out:
# Electronic check             2365
# Mailed check                 1612
# Bank transfer (automatic)    1544
# Credit card (automatic)      1522
# Name: payment_method, dtype: int64

# %%
data['payment_method'] = data['payment_method'].astype('category')

# %%
data['payment_method'].dtypes
# Out:
# CategoricalDtype(categories=['Bank transfer (automatic)', 'Credit card (automatic)',
#                   'Electronic check', 'Mailed check'],
# , ordered=False)

# %%
data['churn'].value_counts()
# Out:
# No     5174
# Yes    1869
# Name: churn, dtype: int64

# %%
data['churn'] = data['churn'].astype('category')

# %%
data['churn'].dtypes
# Out:
# CategoricalDtype(categories=['No', 'Yes'], ordered=False)

# %%
data.dtypes
# Out:
# customer_id            object
# gender               category
# senior_citizen       category
# partner              category
# dependents           category
# tenure                  int64
# phone_service        category
# multiple_lines       category
# internet_service     category
# online_security      category
# online_backup        category
# device_protection    category
# tech_support         category
# streaming_tv         category
# streaming_movies     category
# contract             category
# paperless_billing    category
# payment_method       category
# monthly_charges       float64
# total_charges         float64
# churn                category
# dtype: object

# %% [markdown]
# ### Univariate Analysis - Numerical Variables

# %% [markdown]
# ###### check their properties like:
# - Mean
# - Median
# - Standard Deviation
# - Kurtosis/skewness
# - distribution/range

# %%
# Numerical datatypes
data.select_dtypes(include=['int64','float64','Int64']).dtypes
# Out:
# tenure               int64
# monthly_charges    float64
# total_charges      float64
# dtype: object

# %%
# custom function for easy and efficient analysis of numerical univariate

def UVA_numeric(data, var_group):
  '''
  Univariate_Analysis_numeric
  takes a group of variables (INTEGER and FLOAT) and plot/print all the descriptives and properties along with KDE.

  Runs a loop: calculate all the descriptives of i(th) variable and plot/print it
  '''

  size = len(var_group)
  plt.figure(figsize = (7*size,3), dpi = 100)
  
  #looping for each variable
  for j,i in enumerate(var_group):
    
    # calculating descriptives of variable
    mini = data[i].min()
    maxi = data[i].max()
    ran = data[i].max()-data[i].min()
    mean = data[i].mean()
    median = data[i].median()
    st_dev = data[i].std()
    skew = data[i].skew()
    kurt = data[i].kurtosis()

    # calculating points of standard deviation
    points = mean-st_dev, mean+st_dev

    #Plotting the variable with every information
    plt.subplot(1,size,j+1)
    sns.kdeplot(data[i], shade=True)
#     sns.lineplot(points, [0,0], color = 'black', label = "std_dev")
#     sns.scatterplot([mini,maxi], [0,0], color = 'orange', label = "min/max")
#     sns.scatterplot([mean], [0], color = 'red', label = "mean")
#     sns.scatterplot([median], [0], color = 'blue', label = "median")
    plt.xlabel('{}'.format(i), fontsize = 20)
    plt.ylabel('density')
    plt.title('std_dev = {}; kurtosis = {};\nskew = {}; range = {}\nmean = {}; median = {}'.format((round(points[0],2),round(points[1],2)),
                                                                                                   round(kurt,2),
                                                                                                   round(skew,2),
                                                                                                   (round(mini,2),round(maxi,2),round(ran,2)),
                                                                                                   round(mean,2),
                                                                                                   round(median,2)))

# %%
cols = ['tenure', 'monthly_charges', 'total_charges']
UVA_numeric(data, cols)

# %% [markdown]
# ### Univariate Analysis - Categorical Variables

# %%
# Custom function for easy visualisation of Categorical Variables
def UVA_category(data, var_group):

  '''
  Univariate_Analysis_categorical
  takes a group of variables (category) and plot/print all the value_counts and barplot.
  '''
  # setting figure_size
  size = len(var_group)
  plt.figure(figsize = (7*size,5), dpi = 100)

  # for every variable
  for j,i in enumerate(var_group):
    norm_count = data[i].value_counts(normalize = True)
    n_uni = data[i].nunique()

  #Plotting the variable with every information
    plt.subplot(1,size,j+1)
#     sns.barplot(norm_count, norm_count.index , order = norm_count.index)
    plt.xlabel('fraction/percent', fontsize = 20)
    plt.ylabel('{}'.format(i), fontsize = 20)
    plt.title('n_uniques = {} \n value counts \n {};'.format(n_uni,norm_count))

# %%
data.select_dtypes(exclude=['int64','float64','Int64']).dtypes
# Out:
# customer_id            object
# gender               category
# senior_citizen       category
# partner              category
# dependents           category
# phone_service        category
# multiple_lines       category
# internet_service     category
# online_security      category
# online_backup        category
# device_protection    category
# tech_support         category
# streaming_tv         category
# streaming_movies     category
# contract             category
# paperless_billing    category
# payment_method       category
# churn                category
# dtype: object

# %%
demographics_info = ['customer_id', 'gender', 'senior_citizen', 'partner', 'dependents']
services_info = ['phone_service','multiple_lines','internet_service','online_security', \
                 'online_backup','device_protection','tech_support','streaming_tv',\
                 'streaming_movies', 'contract', 'paperless_billing', 'payment_method']
status_info = ['churn']

# %%
UVA_category(data, demographics_info)

# %%
UVA_category(data, services_info)

# %%
UVA_category(data, ['churn'])

# %% [markdown]
# ### Univariate Missing Values

# %%
# finding number of missing values in every variable
data.isnull().sum()
# Out:
# customer_id           0
# gender                0
# senior_citizen        0
# partner               0
# dependents            0
# tenure                0
# phone_service         0
# multiple_lines        0
# internet_service      0
# online_security       0
# online_backup         0
# device_protection     0
# tech_support          0
# streaming_tv          0
# streaming_movies      0
# contract              0
# paperless_billing     0
# payment_method        0
# monthly_charges       0
# total_charges        11
# churn                 0
# dtype: int64

# %%
# custom function for easy outlier analysis

def UVA_outlier(data, var_group, include_outlier = True):
  '''
  Univariate_Analysis_outlier:
  takes a group of variables (INTEGER and FLOAT) and plot/print boplot and descriptives\n
  Runs a loop: calculate all the descriptives of i(th) variable and plot/print it \n\n

  data : dataframe from which to plot from\n
  var_group : {list} type Group of Continuous variables\n
  include_outlier : {bool} whether to include outliers or not, default = True\n
  '''

  size = len(var_group)
  plt.figure(figsize = (7*size,4), dpi = 100)
  
  #looping for each variable
  for j,i in enumerate(var_group):
    
    # calculating descriptives of variable
    quant25 = float(data[i].quantile(0.25))
    quant75 = float(data[i].quantile(0.75))
    IQR = quant75 - quant25
    med = data[i].median()
    whis_low = quant25-(1.5*IQR)
    whis_high = quant75+(1.5*IQR)

    # Calculating Number of Outliers
    outlier_high = len(data[i][data[i]>whis_high])
    outlier_low = len(data[i][data[i]<whis_low])

    if include_outlier == True:
      #Plotting the variable with every information
      plt.subplot(1,size,j+1)
      sns.boxplot(data[i], orient="v")
      plt.ylabel('{}'.format(i))
      plt.title('With Outliers\nIQR = {}; Median = {} \n 2nd,3rd  quartile = {};\n Outlier (low/high) = {} \n'.format(
                                                                                                   round(IQR,2),
                                                                                                   round(med,2),
                                                                                                   (round(quant25,2),round(quant75,2)),
                                                                                                   (outlier_low,outlier_high)
                                                                                                   ))
      
    else:
      # replacing outliers with max/min whisker
      data2 = data[var_group][:]
      data2[i][data2[i]>whis_high] = whis_high+1
      data2[i][data2[i]<whis_low] = whis_low-1
      
      # plotting without outliers
      plt.subplot(1,size,j+1)
      sns.boxplot(data2[i], orient="v")
      plt.ylabel('{}'.format(i))
      plt.title('Without Outliers\nIQR = {}; Median = {} \n 2nd,3rd  quartile = {};\n Outlier (low/high) = {} \n'.format(
                                                                                                   round(IQR,2),
                                                                                                   round(med,2),
                                                                                                   (round(quant25,2),round(quant75,2)),
                                                                                                   (outlier_low,outlier_high)
                                                                                                   ))

# %%
# UVA_outlier(data, demographics_info)

# %%
# UVA_outlier(data, services_info)

# %%
# UVA_outlier(data, status_info)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[110], line 1
# ----> 1 UVA_outlier(data, status_info)
#
# Cell In[105], line 21, in UVA_outlier(data, var_group, include_outlier)
#      17 #looping for each variable
#      18 for j,i in enumerate(var_group):
#      19
#      20   # calculating descriptives of variable
# ---> 21   quant25 = float(data[i].quantile(0.25))
#      22   quant75 = float(data[i].quantile(0.75))
#      23   IQR = quant75 - quant25
#
# File ~\anaconda3\lib\site-packages\pandas\core\series.py:2497, in Series.quantile(self, q, interpolation)
#    2493 # We dispatch to DataFrame so that core.internals only has to worry
#    2494 #  about 2D cases.
#    2495 df = self.to_frame()
# -> 2497 result = df.quantile(q=q, interpolation=interpolation, numeric_only=False)
#    2498 if result.ndim == 2:
#    2499     result = result.iloc[:, 0]
#
# ...
